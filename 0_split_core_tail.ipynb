# %% [markdown]
# ## Recursive

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import rdkit

def try_n_plus_or_N_plus(base_mol: Chem.Mol) -> str:
    """
    Given a molecule `base_mol` that presumably has exactly one
    quaternary nitrogen [N+]/n+, produce a base SMILES.
    
    Then create two candidate SMILES:
      (1) Replacing every '[N+]' with 'n+'  (the "aromatic" guess)
      (2) Replacing every 'n+'   with '[N+]' (the "aliphatic" guess)
    
    Attempt to sanitize each. If one passes, return that SMILES.
    If both pass, you can decide which to prefer (here we return the first that passes).
    If both fail, return the original base SMILES.
    """
    base_smi = Chem.MolToSmiles(base_mol, isomericSmiles=True)
    
    # Candidate 1: try "n+" in place of "[N+]"
    candidate1_smi = base_smi.replace("[N+]", "n+")
    candidate1_mol = Chem.MolFromSmiles(candidate1_smi)
    if candidate1_mol is not None:
        try:
            Chem.SanitizeMol(candidate1_mol)
            return Chem.MolToSmiles(candidate1_mol, isomericSmiles=True)
        except Exception:
            pass
    
    # Candidate 2: try "[N+]" in place of "n+"
    candidate2_smi = base_smi.replace("n+", "[N+]")
    candidate2_mol = Chem.MolFromSmiles(candidate2_smi)
    if candidate2_mol is not None:
        try:
            Chem.SanitizeMol(candidate2_mol)
            return Chem.MolToSmiles(candidate2_mol, isomericSmiles=True)
        except Exception:
            pass
    
    # If both fail, return the original base SMILES
    return base_smi


def has_min_carbon_chain(mol: Chem.Mol, n: int) -> bool:
    """
    Returns True if `mol` contains a (linear) chain of at least `n` carbons in a row.
    We construct an RDKit SMARTS that looks like: C-C-C-... (n times).
    """
    if mol is None:
        return False
    # e.g. for n=6: pattern = "C-C-C-C-C-C"
    pattern_str = "-".join(["C"] * n)
    pattern = Chem.MolFromSmarts(pattern_str)
    return mol.HasSubstructMatch(pattern)


def cut_once(
    smi: str, 
    min_carbons: int = 6
):
    """
    Attempt to cut the molecule 'smi' at exactly ONE [N+] substituent that:
      - contains no extra [N+],
      - and after removing that [N+], has at least `min_carbons` in a linear chain.

    Returns (sub_frag_smi, remainder_smi) if success,
            (None, None) if no valid cut is found.
    
    Uses the 'try_n_plus_or_N_plus' function to pick the correct N+ label in each piece.
    """
    mol = Chem.MolFromSmiles(smi)
    if mol is None:
        return (None, None)

    # Find all [N+] atoms
    n_plus_indices = [
        a.GetIdx()
        for a in mol.GetAtoms()
        if a.GetAtomicNum() == 7 and a.GetFormalCharge() == 1
    ]
    if not n_plus_indices:
        return (None, None)
    
    for n_idx in n_plus_indices:
        neighbor_indices = [nbr.GetIdx() for nbr in mol.GetAtomWithIdx(n_idx).GetNeighbors()]
        
        for nb_idx in neighbor_indices:
            # BFS for that neighbor
            visited = set([nb_idx])
            queue = [nb_idx]
            while queue:
                curr = queue.pop(0)
                curr_atom = mol.GetAtomWithIdx(curr)
                for nbr in curr_atom.GetNeighbors():
                    nbr_idx = nbr.GetIdx()
                    if nbr_idx == n_idx:
                        continue
                    if nbr_idx not in visited:
                        visited.add(nbr_idx)
                        queue.append(nbr_idx)
            
            # Check if BFS substituent has another N+
            has_other_nplus = any(
                (mol.GetAtomWithIdx(a).GetAtomicNum() == 7 and 
                 mol.GetAtomWithIdx(a).GetFormalCharge() == 1)
                for a in visited
            )
            if has_other_nplus:
                continue
            
            # Build sub-mol with BFS + the chosen [N+]
            atoms_to_keep_sub = visited.union({n_idx})
            rwmol_sub = Chem.RWMol(mol)
            to_remove_sub = sorted(
                [a.GetIdx() for a in rwmol_sub.GetAtoms() 
                 if a.GetIdx() not in atoms_to_keep_sub],
                reverse=True
            )
            for x in to_remove_sub:
                rwmol_sub.RemoveAtom(x)
            sub_mol = rwmol_sub.GetMol()
            
            # Temporarily remove [N+] from sub_mol to check if it has an n-carbon chain
            n_plus_in_sub = [
                a.GetIdx() for a in sub_mol.GetAtoms()
                if a.GetAtomicNum() == 7 and a.GetFormalCharge() == 1
            ]
            if len(n_plus_in_sub) != 1:
                continue
            rwmol_for_chain = Chem.RWMol(sub_mol)
            rwmol_for_chain.RemoveAtom(n_plus_in_sub[0])
            sub_for_chain = rwmol_for_chain.GetMol()
            
            # Check if sub_for_chain has at least `min_carbons` in a row
            if not has_min_carbon_chain(sub_for_chain, min_carbons):
                continue
            
            # Build the remainder (everything except this BFS substituent minus the N index)
            atoms_to_keep_rem = set(range(mol.GetNumAtoms()))
            for vid in visited:
                if vid != n_idx:
                    atoms_to_keep_rem.discard(vid)
            
            rwmol_rem = Chem.RWMol(mol)
            to_remove_rem = sorted(
                [ix for ix in range(mol.GetNumAtoms()) 
                 if ix not in atoms_to_keep_rem],
                reverse=True
            )
            for x in to_remove_rem:
                rwmol_rem.RemoveAtom(x)
            remainder_mol = rwmol_rem.GetMol()
            
            # Fix each piece with "try_n_plus_or_N_plus"
            sub_frag_smi = try_n_plus_or_N_plus(sub_mol)
            remainder_smi = try_n_plus_or_N_plus(remainder_mol)
            
            return (sub_frag_smi, remainder_smi)

    return (None, None)


def cut_once_main(smi: str):
    """
    Tries to cut 'smi' using 6+ carbons first.
    If that fails, tries 4+ carbons.
    Returns (sub_frag_smi, remainder_smi) or (None, None).
    """
    subfrag_6, remainder_6 = cut_once(smi, min_carbons=6)
    if subfrag_6 is not None:
        return (subfrag_6, remainder_6)
    
    # Fall back to 4+ carbons
    return cut_once(smi, min_carbons=4)


def iterative_cut(smi: str, results=None):
    """
    Repeatedly apply `cut_once_main` until no more valid cuts remain.
    Each cut yields:
      - A sub-fragment (the BFS substituent + N+),
      - The remainder, which we keep cutting.
    Once we cannot cut further, we add that final 'smi' as a fragment.
    """
    if results is None:
        results = []
    
    subfrag, remainder = cut_once_main(smi)
    if subfrag is None:
        # No more cuts => add 'smi' as final (with correct labeling)
        mol = Chem.MolFromSmiles(smi)
        if mol is not None:
            final_smi = try_n_plus_or_N_plus(mol)
            results.append(final_smi)
        else:
            results.append(smi)
    else:
        # We made a cut => store the BFS subfragment
        results.append(subfrag)
        # Recursively cut the remainder
        iterative_cut(remainder, results)

    return results


# ------------------- EXAMPLE USAGE ------------------- #
if __name__ == "__main__":
    test_smi = "C[N+](C=C1)=CC=C1C2=CC=[N+](CCCCCCCCCCCCCCCC)C=C2.[Br-].[I-]"
    
    final_fragments = iterative_cut(test_smi)
    
    print("Fragments from iterative one-cut-at-a-time decomposition:")
    for i, frag in enumerate(final_fragments, 1):
        print(f"{i}. {frag}")
# Out:
# Fragments from iterative one-cut-at-a-time decomposition:
# 1. CCCCCCCCCCCCCCCC[n+]
# 2. C[n+]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]
# [06:52:24] non-ring atom 16 marked aromatic
# [06:52:24] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [06:52:24] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [06:52:24] SMILES Parse Error: syntax error while parsing: C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]
# [06:52:24] SMILES Parse Error: Failed parsing SMILES 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]' for input: 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]'
# [06:52:24] SMILES Parse Error: syntax error while parsing: C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]
# [06:52:24] SMILES Parse Error: Failed parsing SMILES 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]' for input: 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]'

# %%
tails = []
cores = []
error_tails = []

all_smi_list = []
with open('qac-0315.txt', "r") as f:
    for line in f:
        smi = line.strip()
        # Skip empty lines or whitespace-only lines
        if not smi:
            continue
        all_smi_list.append(smi)
        fragments = iterative_cut(smi)
        if len(fragments) == 0:
            print(smi)
            break
        core_smi = fragments[-1]
        
        mol_core = Chem.MolFromSmiles(core_smi)
        assert mol_core != None
        cores.append(core_smi)

        for tail_idx in range(len(fragments)-1):
            tail_smi = fragments[tail_idx]
            try:
                mol_tail = Chem.MolFromSmiles(tail_smi)
                assert mol_tail != None
                tails.append(tail_smi)
            except:
                tail_smi = tail_smi.replace("n", "N")
                mol_tail = Chem.MolFromSmiles(tail_smi)
                if mol_tail is not None:
                    tails.append(tail_smi)
                else:
                    error_tails.append(tail_smi)
# Out:
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCn+'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)Cc1ccccc1.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)Cc1ccccc1.[Cl-]' for input: 'Cn+(C)Cc1ccccc1.[Cl-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)Cc1ccccc1.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)Cc1ccccc1.[Cl-]' for input: 'Cn+(C)Cc1ccccc1.[Cl-]'
# [18:49:31] non-ring atom 16 marked aromatic
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: C1=CC=n+C=C1.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'C1=CC=n+C=C1.[Cl-]' for input: 'C1=CC=n+C=C1.[Cl-]'
# [18:49:31] non-ring atom 16 marked aromatic
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCn+
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCn+' for input: 'CCCCCCCCCCn+'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCn+(C)C.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCn+(C)C.[Cl-]' for input: 'CCCCCCCCCCn+(C)C.[Cl-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCn+
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCn+' for input: 'CCCCCCCCCCn+'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+C.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+C.[Cl-]' for input: 'Cn+C.[Cl-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+C.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+C.[Cl-]' for input: 'Cn+C.[Cl-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCn+'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+(C)C.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+(C)C.[Cl-]' for input: 'CCCCCCCCCCCCn+(C)C.[Cl-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCn+'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+C.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+C.[Cl-]' for input: 'Cn+C.[Cl-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+C.[Cl-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+C.[Cl-]' for input: 'Cn+C.[Cl-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCn+'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCn+
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCCCCCn+'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCOc1cccc(Cn+(C)(C)C)c1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCOc1cccc(Cn+(C)(C)C)c1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCOc1cccc(Cn+(C)(C)C)c1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCOc1ccc(Cn+(C)(C)C)cc1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCOc1ccc(Cn+(C)(C)C)cc1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCOc1ccc(Cn+(C)(C)C)cc1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)ccc1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCOc1c(Cn+(C)(C)C)cccc1Cn+(C)(C)C.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCOc1c(Cn+(C)(C)C)cccc1Cn+(C)(C)C.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCOc1c(Cn+(C)(C)C)cccc1Cn+(C)(C)C.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)cc(Cn+(C)(C)C)c1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)cc(Cn+(C)(C)C)c1.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)cc(Cn+(C)(C)C)c1.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)cc(Cn+(C)(C)C)c1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)cc(Cn+(C)(C)C)c1.[Br-].[Br-]' for input: 'CCCCCCCCCCCCCCCCOc1cc(Cn+(C)(C)C)cc(Cn+(C)(C)C)c1.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCOc1ccc(Cn+)cc1
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCOc1ccc(Cn+)cc1' for input: 'CCCCCCCCCCOc1ccc(Cn+)cc1'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCOc1ccc(Cn+)cc1
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCOc1ccc(Cn+)cc1' for input: 'CCCCCCCCCCCCCCOc1ccc(Cn+)cc1'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: Cn+(C)C.[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'Cn+(C)C.[Br-]' for input: 'Cn+(C)C.[Br-]'
# [18:49:31] non-ring atom 8 marked aromatic
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCC[[N+]]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[[N+]]' for input: 'CCCCCCCC[[N+]]'
# [18:49:31] non-ring atom 8 marked aromatic
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCC[[N+]]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[[N+]]' for input: 'CCCCCCCC[[N+]]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:31] non-ring atom 8 marked aromatic
# [18:49:31] non-ring atom 8 marked aromatic
# [18:49:31] non-ring atom 10 marked aromatic
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:31] non-ring atom 10 marked aromatic
# [18:49:31] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:31] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:31] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:31] non-ring atom 10 marked aromatic
# [18:49:31] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 13 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 13 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 13 marked aromatic
# [18:49:32] non-ring atom 13 marked aromatic
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2ccncc2)=CC=n+1.[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2ccncc2)=CC=n+1.[Br-]' for input: 'C1=CC(c2ccncc2)=CC=n+1.[Br-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]' for input: 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]' for input: 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]' for input: 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]' for input: 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]' for input: 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]' for input: 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]'
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]' for input: 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]' for input: 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]'
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2ccncc2)=CC=n+1.[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2ccncc2)=CC=n+1.[Br-]' for input: 'C1=CC(c2ccncc2)=CC=n+1.[Br-]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]' for input: 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]' for input: 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]' for input: 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]' for input: 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2ccncc2)=CC=n+1.[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2ccncc2)=CC=n+1.[Br-]' for input: 'C1=CC(c2ccncc2)=CC=n+1.[Br-]'
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]' for input: 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]' for input: 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]'
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]' for input: 'CC[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]' for input: 'CC[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[Br-]'
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] non-ring atom 20 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2ccncc2)=CC=n+1.[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2ccncc2)=CC=n+1.[Br-]' for input: 'C1=CC(c2ccncc2)=CC=n+1.[Br-]'
# [18:49:32] non-ring atom 20 marked aromatic
# [18:49:32] non-ring atom 20 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]' for input: 'C[n+]1ccc(C2=CC=n+C=C2)cc1.[Br-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]' for input: 'C[[N+]]1ccc(C2=CC=[N+]C=C2)cc1.[Br-].[I-]'
# [18:49:32] non-ring atom 20 marked aromatic
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]'
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]'
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 11 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Cl-].[Cl-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Cl-].[Cl-]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[I-].[I-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[I-].[I-]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 12 marked aromatic
# [18:49:32] non-ring atom 10 marked aromatic
# [18:49:32] non-ring atom 8 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[[N+]]' for input: 'CCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 8 marked aromatic
# [18:49:32] non-ring atom 14 marked aromatic
# [18:49:32] non-ring atom 6 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCC[[N+]]' for input: 'CCCCCC[[N+]]'
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(c2cc[n+]cc2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]' for input: 'C1=CC(c2cc[[N+]]cc2)=CC=[N+]1.[Br-].[Br-]'
# [18:49:32] SMILES Parse Error: syntax error while parsing: C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]' for input: 'C1=CC(C2=CC=n+C=C2)=CC=n+1.[Br-].[Br-]'
# [18:49:32] non-ring atom 6 marked aromatic
# [18:49:32] non-ring atom 16 marked aromatic
# [18:49:32] non-ring atom 18 marked aromatic
# [18:49:32] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCCCCCCC[[N+]]
# [18:49:32] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCCCCCCCCC[[N+]]'
# [18:49:32] non-ring atom 4 marked aromatic
# ...
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+(C)Cc1cc(Cn+C)cc(Cn+(C)(CCCCCCCCCCCC)CCCCCCCCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+(C)Cc1cc(Cn+C)cc(Cn+(C)(CCCCCCCCCCCC)CCCCCCCCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCCCCCn+(C)Cc1cc(Cn+C)cc(Cn+(C)(CCCCCCCCCCCC)CCCCCCCCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+(C)(CCCCCCCCCCCC)Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+(C)(CCCCCCCCCCCC)Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCCCCCn+(C)(CCCCCCCCCCCC)Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+(C)Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+(C)Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCCCCCn+(C)Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCCCn+' for input: 'CCCCCCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: Cn+Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'Cn+Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]' for input: 'Cn+Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: Cn+Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'Cn+Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]' for input: 'Cn+Cc1cc(Cn+C)cc(Cn+C)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+(CCCC)Cc1cc(Cn+(CCCC)(CCCC)CCCC)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+(CCCC)Cc1cc(Cn+(CCCC)(CCCC)CCCC)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+(CCCC)Cc1cc(Cn+(CCCC)(CCCC)CCCC)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+Cc1cc(Cn+(CCCC)(CCCC)CCCC)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+Cc1cc(Cn+(CCCC)(CCCC)CCCC)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+Cc1cc(Cn+(CCCC)(CCCC)CCCC)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+(CCCC)(CCCC)Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+(CCCC)(CCCC)Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+(CCCC)(CCCC)Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+(CCCC)Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+(CCCC)Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+(CCCC)Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+Cc1cc(Cn+)cc(Cn+(CCCC)(CCCC)CCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+(CCCC)(CCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+(CCCC)(CCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+(CCCC)(CCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+(CCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+(CCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+(CCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCn+' for input: 'CCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: [Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1
# [18:49:35] SMILES Parse Error: Failed parsing SMILES '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1' for input: '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1'
# [18:49:35] SMILES Parse Error: syntax error while parsing: [Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1
# [18:49:35] SMILES Parse Error: Failed parsing SMILES '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1' for input: '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+(CCCCCC)Cc1cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+(CCCCCC)Cc1cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+(CCCCCC)Cc1cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+Cc1cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+Cc1cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+Cc1cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+(CCCCCC)(CCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+(CCCCCC)(CCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+(CCCCCC)(CCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+(CCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+(CCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+(CCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+Cc1cc(Cn+)cc(Cn+(CCCCCC)(CCCCCC)CCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+(CCCCCC)(CCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+(CCCCCC)(CCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+(CCCCCC)(CCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+(CCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+(CCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+(CCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCn+' for input: 'CCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: [Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1
# [18:49:35] SMILES Parse Error: Failed parsing SMILES '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1' for input: '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1'
# [18:49:35] SMILES Parse Error: syntax error while parsing: [Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1
# [18:49:35] SMILES Parse Error: Failed parsing SMILES '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1' for input: '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+Cc1cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+Cc1cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+Cc1cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+(CCCCCCCC)(CCCCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+(CCCCCCCC)(CCCCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+(CCCCCCCC)(CCCCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+Cc1cc(Cn+)cc(Cn+(CCCCCCCC)(CCCCCCCC)CCCCCCCC)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+(CCCCCCCC)(CCCCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+(CCCCCCCC)(CCCCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+(CCCCCCCC)(CCCCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+(CCCCCCCC)Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]' for input: 'CCCCCCCCn+Cc1cc(Cn+)cc(Cn+)c1.[Br-].[Br-].[Br-]'
# [18:49:35] SMILES Parse Error: syntax error while parsing: CCCCCCCCn+
# [18:49:35] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCn+' for input: 'CCCCCCCCn+'
# [18:49:35] SMILES Parse Error: syntax error while parsing: [Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1
# [18:49:35] SMILES Parse Error: Failed parsing SMILES '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1' for input: '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1'
# [18:49:35] SMILES Parse Error: syntax error while parsing: [Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1
# [18:49:35] SMILES Parse Error: Failed parsing SMILES '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1' for input: '[Br-].[Br-].[Br-].n+Cc1cc(Cn+)cc(Cn+)c1'

# %%
# Writing to a file using a for loop
with open('0315-cores.txt', 'w', encoding='utf-8') as file:
    for line in set(cores):
        file.write(line + '\n')  # Adding a newline character

# %%
smi = all_smi_list[90]
fragments = iterative_cut(smi)

# Add them to our collections
print(smi)
print(fragments)
# Out:
# CCCCCCCCCCC[N+]1=CC(C2=CC=[N+](CCCCCCCCCCC)C=C2)=CC=C1.[Br-].[Br-]
# ['CCCCCCCCCCC[n+]', 'CCCCCCCCCCC[n+]', 'C1=C[N+]=CC(C2=CC=[N+]C=C2)=C1.[Br-].[Br-]']
# [18:44:47] non-ring atom 11 marked aromatic
# [18:44:47] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:44:47] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:44:47] non-ring atom 11 marked aromatic
# [18:44:47] SMILES Parse Error: syntax error while parsing: CCCCCCCCCCC[[N+]]
# [18:44:47] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCCC[[N+]]' for input: 'CCCCCCCCCCC[[N+]]'
# [18:44:47] SMILES Parse Error: syntax error while parsing: C1=Cn+=CC(c2cc[n+]cc2)=C1.[Br-].[Br-]
# [18:44:47] SMILES Parse Error: Failed parsing SMILES 'C1=Cn+=CC(c2cc[n+]cc2)=C1.[Br-].[Br-]' for input: 'C1=Cn+=CC(c2cc[n+]cc2)=C1.[Br-].[Br-]'
# [18:44:47] SMILES Parse Error: syntax error while parsing: C1=C[N+]=CC(c2cc[[N+]]cc2)=C1.[Br-].[Br-]
# [18:44:47] SMILES Parse Error: Failed parsing SMILES 'C1=C[N+]=CC(c2cc[[N+]]cc2)=C1.[Br-].[Br-]' for input: 'C1=C[N+]=CC(c2cc[[N+]]cc2)=C1.[Br-].[Br-]'
# [18:44:47] SMILES Parse Error: syntax error while parsing: C1=Cn+=CC(C2=CC=n+C=C2)=C1.[Br-].[Br-]
# [18:44:47] SMILES Parse Error: Failed parsing SMILES 'C1=Cn+=CC(C2=CC=n+C=C2)=C1.[Br-].[Br-]' for input: 'C1=Cn+=CC(C2=CC=n+C=C2)=C1.[Br-].[Br-]'

# %%
fragments = iterative_cut("O=C(C[N+]1=CC=C(CN(CC2=CC=[N+](C=C2)CC(OCCCCCC)=O)CC3=CC=[N+](C=C3)CC(OCCCCCC)=O)C=C1)OCCCCCC")
fragments
# Out:
# [06:53:08] non-ring atom 10 marked aromatic
# [06:53:08] SMILES Parse Error: syntax error while parsing: CCCCCCOC(=O)C[[N+]]
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCOC(=O)C[[N+]]' for input: 'CCCCCCOC(=O)C[[N+]]'
# [06:53:08] non-ring atom 10 marked aromatic
# [06:53:08] SMILES Parse Error: syntax error while parsing: CCCCCCOC(=O)C[[N+]]
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCOC(=O)C[[N+]]' for input: 'CCCCCCOC(=O)C[[N+]]'
# [06:53:08] SMILES Parse Error: syntax error while parsing: CCCCCCOC(=O)C[n+]1ccc(CN(CC2=CC=n+C=C2)Cc2cc[n+]cc2)cc1
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCOC(=O)C[n+]1ccc(CN(CC2=CC=n+C=C2)Cc2cc[n+]cc2)cc1' for input: 'CCCCCCOC(=O)C[n+]1ccc(CN(CC2=CC=n+C=C2)Cc2cc[n+]cc2)cc1'
# [06:53:08] SMILES Parse Error: syntax error while parsing: CCCCCCOC(=O)C[[N+]]1ccc(CN(CC2=CC=[N+]C=C2)Cc2cc[[N+]]cc2)cc1
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCOC(=O)C[[N+]]1ccc(CN(CC2=CC=[N+]C=C2)Cc2cc[[N+]]cc2)cc1' for input: 'CCCCCCOC(=O)C[[N+]]1ccc(CN(CC2=CC=[N+]C=C2)Cc2cc[[N+]]cc2)cc1'
# [06:53:08] non-ring atom 10 marked aromatic
# [06:53:08] SMILES Parse Error: syntax error while parsing: CCCCCCOC(=O)C[[N+]]
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCOC(=O)C[[N+]]' for input: 'CCCCCCOC(=O)C[[N+]]'
# [06:53:08] SMILES Parse Error: syntax error while parsing: C1=CC(CN(CC2=CC=n+C=C2)Cc2cc[n+]cc2)=CC=n+1
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'C1=CC(CN(CC2=CC=n+C=C2)Cc2cc[n+]cc2)=CC=n+1' for input: 'C1=CC(CN(CC2=CC=n+C=C2)Cc2cc[n+]cc2)=CC=n+1'
# [06:53:08] SMILES Parse Error: syntax error while parsing: C1=CC(CN(CC2=CC=[N+]C=C2)Cc2cc[[N+]]cc2)=CC=[N+]1
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'C1=CC(CN(CC2=CC=[N+]C=C2)Cc2cc[[N+]]cc2)=CC=[N+]1' for input: 'C1=CC(CN(CC2=CC=[N+]C=C2)Cc2cc[[N+]]cc2)=CC=[N+]1'
# [06:53:08] SMILES Parse Error: syntax error while parsing: C1=CC(CN(CC2=CC=n+C=C2)CC2=CC=n+C=C2)=CC=n+1
# [06:53:08] SMILES Parse Error: Failed parsing SMILES 'C1=CC(CN(CC2=CC=n+C=C2)CC2=CC=n+C=C2)=CC=n+1' for input: 'C1=CC(CN(CC2=CC=n+C=C2)CC2=CC=n+C=C2)=CC=n+1'
# ['CCCCCCOC(=O)C[n+]',
#  'CCCCCCOC(=O)C[n+]',
#  'CCCCCCOC(=O)C[n+]',
#  'C1=CC(CN(CC2=CC=[N+]C=C2)CC2=CC=[N+]C=C2)=CC=[N+]1']
